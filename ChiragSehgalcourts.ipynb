# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("a5b71bfa-840c-4c86-8f43-07a9ae854227.csv")
df = df.dropna(1)
df.head(246)
# Out:
# <ipython-input-3-c631548f728b>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df = df.dropna(1)
#              id                                   name               type  \
# 0    1592343416   Allegheny Commons Basketball Court 1  Basketball (Full)
# 1    1365248699  Allegheny Commons Park Tennis Court 1             Tennis
# 2    1757180821  Allegheny Commons Park Tennis Court 2             Tennis
# 3     744303307  Allegheny Commons Park Tennis Court 3             Tennis
# 4    1157777481          Alton Park Basketball Court 1  Basketball (Half)
# ..          ...                                    ...                ...
# 241  1256692000          Riverview Park Tennis Court 2             Tennis
# 242  1802795636         West End Park Basketball Court  Basketball (Half)
# 243   529313558          Frick Park Pickleball Court 1         Pickleball
# 244  1330544431          Frick Park Pickleball Court 2         Pickleball
# 245    30730620          Frick Park Pickleball Court 3         Pickleball
#
#                   park  grandstand         neighborhood  council_district  \
# 0    Allegheny Commons           0     Allegheny Center                 1
# 1    Allegheny Commons           0     Allegheny Center                 1
# 2    Allegheny Commons           0     Allegheny Center                 1
# 3    Allegheny Commons           0     Allegheny Center                 1
# 4           Alton Park           0            Beechview                 4
# ..                 ...         ...                  ...               ...
# 241     Riverview Park           0          Perry North                 1
# 242      West End Park           0              Elliott                 2
# 243         Frick Park           0  Squirrel Hill South                 5
# 244         Frick Park           0  Squirrel Hill South                 5
# 245         Frick Park           0  Squirrel Hill South                 5
#
#      ward        tract  public_works_division  pli_division  police_zone  \
# 0      22  42003562700                      1            22            1
# 1      22  42003562700                      1            22            1
# 2      22  42003562700                      1            22            1
# 3      22  42003562700                      1            22            1
# 4      19  42003191600                      5            19            6
# ..    ...          ...                    ...           ...          ...
# 241    26  42003980400                      1            26            1
# 242    20  42003562600                      5            20            6
# 243    14  42003980300                      3            14            4
# 244    14  42003980300                      3            14            4
# 245    14  42003980300                      3            14            4
#
#     fire_zone   latitude  longitude
# 0         1-7  40.454443 -80.008104
# 1         1-7  40.452400 -80.012531
# 2         1-7  40.452238 -80.012150
# 3         1-7  40.452075 -80.011767
# 4        4-28  40.414152 -80.022305
# ..        ...        ...        ...
# 241      1-15  40.482342 -80.022263
# 242      1-17  40.437395 -80.036929
# 243      2-21  40.429997 -79.914029
# 244      2-21  40.429906 -79.914023
# 245      2-21  40.429826 -79.914017
#
# [246 rows x 15 columns]

# %%
data = pd.read_csv("a5b71bfa-840c-4c86-8f43-07a9ae854227.csv", index_col="neighborhood", parse_dates=True)
data.head(246)
# Out:
#                              id                                   name  \
# neighborhood
# Allegheny Center     1592343416   Allegheny Commons Basketball Court 1
# Allegheny Center     1365248699  Allegheny Commons Park Tennis Court 1
# Allegheny Center     1757180821  Allegheny Commons Park Tennis Court 2
# Allegheny Center      744303307  Allegheny Commons Park Tennis Court 3
# Beechview            1157777481          Alton Park Basketball Court 1
# ...                         ...                                    ...
# Perry North          1256692000          Riverview Park Tennis Court 2
# Elliott              1802795636         West End Park Basketball Court
# Squirrel Hill South   529313558          Frick Park Pickleball Court 1
# Squirrel Hill South  1330544431          Frick Park Pickleball Court 2
# Squirrel Hill South    30730620          Frick Park Pickleball Court 3
#
#                                   type               park location  \
# neighborhood
# Allegheny Center     Basketball (Full)  Allegheny Commons      NaN
# Allegheny Center                Tennis  Allegheny Commons      NaN
# Allegheny Center                Tennis  Allegheny Commons      NaN
# Allegheny Center                Tennis  Allegheny Commons      NaN
# Beechview            Basketball (Half)         Alton Park      NaN
# ...                                ...                ...      ...
# Perry North                     Tennis     Riverview Park      NaN
# Elliott              Basketball (Half)      West End Park      NaN
# Squirrel Hill South         Pickleball         Frick Park      NaN
# Squirrel Hill South         Pickleball         Frick Park      NaN
# Squirrel Hill South         Pickleball         Frick Park      NaN
#
#                     surface_material  grandstand inactive  council_district  \
# neighborhood
# Allegheny Center                 NaN           0        f                 1
# Allegheny Center             Asphalt           0        f                 1
# Allegheny Center             Asphalt           0        f                 1
# Allegheny Center             Asphalt           0        f                 1
# Beechview                    Asphalt           0        f                 4
# ...                              ...         ...      ...               ...
# Perry North                      NaN           0      NaN                 1
# Elliott                      Asphalt           0      NaN                 2
# Squirrel Hill South          Asphalt           0      NaN                 5
# Squirrel Hill South          Asphalt           0      NaN                 5
# Squirrel Hill South          Asphalt           0      NaN                 5
#
#                      ward        tract  public_works_division  pli_division  \
# neighborhood
# Allegheny Center       22  42003562700                      1            22
# Allegheny Center       22  42003562700                      1            22
# Allegheny Center       22  42003562700                      1            22
# Allegheny Center       22  42003562700                      1            22
# Beechview              19  42003191600                      5            19
# ...                   ...          ...                    ...           ...
# Perry North            26  42003980400                      1            26
# Elliott                20  42003562600                      5            20
# Squirrel Hill South    14  42003980300                      3            14
# Squirrel Hill South    14  42003980300                      3            14
# Squirrel Hill South    14  42003980300                      3            14
#
#                      police_zone fire_zone   latitude  longitude
# neighborhood
# Allegheny Center               1       1-7  40.454443 -80.008104
# Allegheny Center               1       1-7  40.452400 -80.012531
# Allegheny Center               1       1-7  40.452238 -80.012150
# Allegheny Center               1       1-7  40.452075 -80.011767
# Beechview                      6      4-28  40.414152 -80.022305
# ...                          ...       ...        ...        ...
# Perry North                    1      1-15  40.482342 -80.022263
# Elliott                        6      1-17  40.437395 -80.036929
# Squirrel Hill South            4      2-21  40.429997 -79.914029
# Squirrel Hill South            4      2-21  40.429906 -79.914023
# Squirrel Hill South            4      2-21  40.429826 -79.914017
#
# [246 rows x 17 columns]

# %%
import csv

with open('a5b71bfa-840c-4c86-8f43-07a9ae854227.csv') as f:
    center_neighborhood_pandas = [row for row in csv.reader(f)]

# %%
center_counter = dict()

for row in center_neighborhood_pandas[1:]:
    center = row[8]
    
    if center not in center_counter:
        center_counter[center] = 1
    else:
        center_counter[center] = center_counter[center] + 1
center_counter
# Out:
# {'Allegheny Center': 9,
#  'Beechview': 7,
#  'Bedford Dwellings': 2,
#  'South Side Slopes': 6,
#  'South Side Flats': 5,
#  'Lower Lawrenceville': 6,
#  'Crawford-Roberts': 2,
#  'Banksville': 3,
#  'Bon Air': 1,
#  'Central Oakland': 1,
#  'Brighton Heights': 2,
#  'Brookline': 9,
#  'Hazelwood': 10,
#  'Lincoln-Lemington-Belmar': 2,
#  'Troy Hill': 8,
#  'Perry South': 1,
#  'Homewood West': 1,
#  'Squirrel Hill South': 26,
#  'Strip District': 1,
#  'Stanton Heights': 2,
#  'Crafton Heights': 3,
#  'Upper Lawrenceville': 2,
#  'East Carnegie': 2,
#  'East Hills': 2,
#  'Duquesne Heights': 2,
#  'Allentown': 1,
#  'Mount Washington': 5,
#  'East Liberty': 6,
#  'Fairywood': 2,
#  'Fineview': 2,
#  'Garfield': 3,
#  'Greenfield': 5,
#  'South Oakland': 2,
#  'Point Breeze': 2,
#  'Regent Square': 6,
#  'Hays': 1,
#  'Elliott': 5,
#  'Morningside': 4,
#  'Highland Park': 20,
#  'Central Northside': 2,
#  'Terrace Village': 5,
#  'Larimer': 1,
#  'Spring Hill-City View': 4,
#  'Carrick': 3,
#  'Central Lawrenceville': 1,
#  'Manchester': 6,
#  'Marshall-Shadeland': 1,
#  'Lincoln Place': 4,
#  'Sheraden': 6,
#  'Beltzhoover': 9,
#  'Shadyside': 2,
#  'Oakwood': 3,
#  'Bloomfield': 5,
#  'Upper Hill': 1,
#  'New Homestead': 2,
#  'Spring Garden': 2,
#  'Middle Hill': 1,
#  'West End': 2,
#  'Polish Hill': 1,
#  'Squirrel Hill North': 1,
#  'Point Breeze North': 1,
#  'Swisshelm Park': 2,
#  'Perry North': 2}

# %%
different_courts = data.groupby("type")['id'].count()
different_courts = different_courts.sort_values()
different_courts
# Out:
# type
# Horseshoe Pit         2
# Lawn Bowling          2
# Dek Hockey            5
# Volleyball            5
# General Sports        6
# Bocce                 8
# Street Hockey         8
# Pickleball           12
# Hockey               14
# Basketball (Half)    23
# Tennis               73
# Basketball (Full)    88
# Name: id, dtype: int64

# %%
different_courts.plot.bar()
